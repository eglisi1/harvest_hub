# %% [markdown]
# # Scrape data from [Schweizer Bauern](https://www.hofsuche.schweizerbauern.ch)

# %% [markdown]
# ## filter data
# We're only interested in farms from zurich, so we filter the data accordingly (``extSearch.query.q=Zürich``): https://www.hofsuche.schweizerbauern.ch/de?extSearch.query.q=Zürich&project=vomhof&extSearch=true

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from time import sleep

options = Options()
options.headless = True
driver = webdriver.Chrome(options=options)

farm_data = [] 

try:
    driver.get(
        "https://www.hofsuche.schweizerbauern.ch/de?extSearch.query.q=Zürich&project=vomhof&extSearch=true"
    )
    sleep(5)

    # Click the "Mehr laden" button until it's no longer available or a set number of times to load all content
    while True:
        # Scroll to the bottom of the page
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        sleep(2)  # wait for the page to scroll down and content to load

        try:
            load_more_button = driver.find_element(
                By.XPATH, '//button[contains(., "Mehr laden")]'
            )
            load_more_button.click()
            sleep(4)  # wait for the content to load after clicking
        except Exception as e:
            print("All content loaded or button not found.")
            break

    # Extract the required data
    farm_cards = driver.find_elements(By.CSS_SELECTOR, 'a[href*="/de/farm/"]')
    for card in farm_cards:
        href = card.get_attribute("href")
        title = card.find_element(By.CSS_SELECTOR, "div.card.de").get_attribute("title")
        farm_data.append({"title": title, "url": href})

finally:
    driver.quit()

print(farm_data)
# Out:
# All content loaded or button not found.
# [{'title': 'Flower Top, 8046  Zürich', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/flower-top-9766/vomhof'}, {'title': 'Ritzmann-Müller Betriebsgemeinschaft, 8459 Volken', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/ritzmann-mueller-betriebsgemeinschaft-13796/vomhof'}, {'title': 'Bauernhof Familie Werffeli, 8104 Weiningen', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/bauernhof-familie-werffeli-9118/vomhof'}, {'title': 'Hof zur Au, 8165 Schleinikon', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/hof-zur-au-12143/vomhof'}, {'title': 'Sonnhaldenhof, 5610 Wohlen', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/sonnhaldenhof-9121/vomhof'}, {'title': 'Streulis Privatbrennerei, 8810 Horgen', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/streulis-privatbrennerei-9652/vomhof'}, {'title': 'Bio Waidhof, 8052 Zürich', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/bio-waidhof-421/vomhof'}, {'title': 'Gfellerhof und Kämatten, 8051 Zürich', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/gfellerhof-und-kaematten-1253/vomhof'}, {'title': 'Schumacher Agrobetrieb, 8046 Zürich', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/schumacher-agrobetrieb-11926/vomhof'}, {'title': 'Riedenholzhof, 8052 Zürich', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/riedenholzhof-720/vomhof'}, {'title': 'Pfister Gemüsebau, 8427 Freienstein', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/pfister-gemuesebau-11821/vomhof'}, {'title': 'Gutsbetrieb Oeschberg, 3425 Koppigen', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/gutsbetrieb-oeschberg-1906/vomhof'}, {'title': 'peter-rickenbach.ch, 8545 Rickenbach', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/peter-rickenbach-ch-9613/vomhof'}, {'title': 'Bihr Rosengartenprodukte, 8344 Bäretswil', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/bihr-rosengartenprodukte-8876/vomhof'}, {'title': 'Gemüsebau Rinderknecht, 8427 Freienstein', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/gemuesebau-rinderknecht-9940/vomhof'}, {'title': 'Hofladen Langwies, Ringlikon, 8142 Uitikon Waldegg', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/hofladen-langwies-ringlikon-796/vomhof'}, {'title': 'Steigacher, 8311 Brütten', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/steigacher-1956/vomhof'}, {'title': 'Brachland, 8608 Bubikon', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/brachland-1242/vomhof'}, {'title': 'Weingut Gehring, 8427  Freienstein', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/weingut-gehring-9763/vomhof'}, {'title': 'Widem, 8164 Bachs', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/widem-1997/vomhof'}, {'title': 'Gutsbetrieb Uf-Stocken, 8802 Kilchberg', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/gutsbetrieb-uf-stocken-1259/vomhof'}, {'title': 'Brachers Blumenfeld, 3423 Ersigen', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/brachers-blumenfeld-12369/vomhof'}, {'title': 'Bergli Christbaum, 8707 Uetikon am See', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/bergli-christbaum-11134/vomhof'}, {'title': 'Gemüse vom Ankenhof, 8102 Oberengstringen', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/gemuese-vom-ankenhof-10116/vomhof'}, {'title': 'Egghof, 3429 Höchstetten', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/egghof-10590/vomhof'}, {'title': 'Litzibuch, 8966 Oberwil-Lieli', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/litzibuch-292/vomhof'}, {'title': 'BungertHof, 8415 Berg am Irchel', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/bungerthof-15182/vomhof'}, {'title': 'Traub Bio-Gemüse Eichhof, 5608 Stetten', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/traub-bio-gemuese-eichhof-11913/vomhof'}, {'title': 'Hofkäserei im Basi, 8953 Dietikon', 'url': 'https://www.hofsuche.schweizerbauern.ch/de/farm/hofkaeserei-im-basi-11380/vomhof'}, {'title': 'Erdbeer- und ...

# %%
import csv

with open('../data/farm_overview.csv', mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Title', 'URL'])

        for farm in farm_data:
            writer.writerow([farm['title'], farm['url']])

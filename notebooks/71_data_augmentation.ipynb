# %% [markdown]
# # Data augmentation

# %%
## Load data

# %%
import geopandas as gpd

gdf = gpd.read_file("../data/processed_data/top_building_per_municipality_with_isochrones.geojson")

# %% [markdown]
# ## filter the buildings with the highest population

# %%
def sort_gdf_by_population_and_rename(gdf, column_name, amount=3):
    # Convert the column's stringified JSON to actual JSON and then extract the population data
    gdf["total_pop"] = gdf.apply(
        lambda row: (
            row[column_name]["features"][0]["properties"]["total_pop"]
            if row[column_name] is not None
            else None
        ),
        axis=1,
    )

    # Remove rows where population data is not available
    gdf = gdf.dropna(subset=["total_pop"])

    # Sort the DataFrame based on the total population in descending order
    sorted_gdf = gdf.sort_values(by="total_pop", ascending=False)

    # Drop all columns starting with "isochrone" except the one used for sorting
    columns_to_keep = [col for col in sorted_gdf.columns if not col.startswith("isochrone") or col == column_name]
    sorted_gdf = sorted_gdf[columns_to_keep]

    # Rename the remaining isochrone column to "isochrone_data"
    sorted_gdf = sorted_gdf.rename(columns={column_name: "isochrone_data"})

    return sorted_gdf.head(amount)

# %% [markdown]
# ## ranking for sochrone_within_15_mode_driving-car

# %%
sorted_gdf = sort_gdf_by_population_and_rename(gdf, 'isochrone_within_15_mode_driving-car')

import json
import folium

column_name = "isochrone_data"

# using Zurich as a default location
map_center = [47.3769, 8.5417]

# Initialize the map
m = folium.Map(location=map_center, zoom_start=10, tiles="CartoDB positron")

# Step 2: Add isochrones to the map
for idx, row in sorted_gdf.iterrows():
    if column_name in row and row[column_name]:
        try:
            isochrone_data = row[column_name]

            # Extract the center coordinates if they exist
            center_coords = isochrone_data["features"][0]["properties"].get("center", None)

            # Add the GeoJson layer representing the isochrone area
            folium.GeoJson(
                isochrone_data,
                name=f"Isochrone {idx}",
                style_function=lambda feature: {
                    "fillColor": "#EC407A",
                    "color": "#000000",
                    "weight": 2,
                    "dashArray": "5, 5",
                    "fillOpacity": 0.5,
                }
            ).add_to(m)

            # If center coordinates are available, add a marker
            if center_coords:
                folium.CircleMarker(
                    location=[center_coords[1], center_coords[0]],  # Lat, Long (reversed from GeoJSON)
                    radius=5,
                    color="red",
                    fill=True,
                    fill_color="red",
                    fill_opacity=1.0,
                    popup=f"Isochrone {idx} Center"
                ).add_to(m)
        except (json.JSONDecodeError, KeyError, IndexError) as e:
            print(f"Failed to handle row {idx}: {e}")

# Add layer control to toggle layers
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58f25539322df1f3077a458c511b3470 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58f25539322df1f3077a458c511b3470&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58f25539322df1f3077a458c511b3470 = L.map(
#                 &quot;map_58f25539322df1f3077a458c511b3470&quot;,
#                 {
#                     center: [47.3769, 8.5417],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69a3e710ea2e5891a09cc3e212fdcddc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_69a3e710ea2e5891a09cc3e212fdcddc.addTo(map_58f25539322df1f3077a458c511b3470);
#
#
#         function geo_json_584d72f421f6284a4e05cae3fd9a44fd_styler(feature) {
#             switch(feature.properties.group_index) {
#                 default:
#                     return {&quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#EC407A&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_584d72f421f6284a4e05cae3fd9a44fd_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_584d72f421f6284a4e05cae3fd9a44fd = L.geoJson(null, {
#                 onEachFeature: geo_json_584d72f421f6284a4e05cae3fd9a44fd_onEachFeature,
#
#                 style: geo_json_584d72f421f6284a4e05cae3fd9a44fd_styler,
#         });
#
#         function geo_json_584d72f421f6284a4e05cae3fd9a44fd_add (data) {
#             geo_json_584d72f421f6284a4e05cae3fd9a44fd
#                 .addData(data);
#         }
#             geo_json_584d72f421f6284a4e05cae3fd9a44fd_add({&quot;bbox&quot;: [8.334477, 47.368345, 8.685848, 47.506685], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.338461, 47.447076], [8.34036, 47.444467], [8.3422, 47.441957], [8.343493, 47.440205], [8.345381, 47.438422], [8.345889, 47.438029], [8.350419, 47.434756], [8.351461, 47.434293], [8.353169, 47.433604], [8.360119, 47.43037], [8.36102, 47.429902], [8.362173, 47.429345], [8.363237, 47.428896], [8.364123, 47.428555], [8.36605, 47.427865], [8.368641, 47.426956], [8.370838, 47.426185], [8.373035, 47.425415], [8.375811, 47.424445], [8.378585, 47.423475], [8.383289, 47.41703], [8.383023, 47.414773], [8.385404, 47.412072], [8.385715, 47.412347], [8.387765, 47.413938], [8.387961, 47.414111], [8.396057, 47.411546], [8.396159, 47.409863], [8.39655, 47.40798], [8.401097, 47.404017], [8.401253, 47.403944], [8.401344, 47.403912], [8.402497, 47.395186], [8.401674, 47.394729], [8.403421, 47.391581], [8.407106, 47.391501], [8.412289, 47.386321], [8.413606, 47.383368], [8.414435, 47.381372], [8.414821, 47.380097], [8.415126, 47.379258], [8.415338, 47.378774], [8.417744, 47.371043], [8.41812, 47.370191], [8.418461, 47.369815], [8.420185, 47.368345], [8.423061, 47.370509], [8.421053, 47.375158], [8.420699, 47.37615], [8.420433, 47.376792], [8.420126, 47.377444], [8.418973, 47.379535], [8.418208, 47.381317], [8.417882, 47.382409], [8.417614, 47.383246], [8.418631, 47.390183], [8.420856, 47.392363], [8.421499, 47.393857], [8.424785, 47.400004], [8.432421, 47.404066], [8.434969, 47.401522], [8.439942, 47.400563], [8.447297, 47.397876], [8.447745, 47.397908], [8.447986, 47.397928], [8.448496, 47.398039], [8.452173, 47.39901], [8.453693, 47.40015], [8.454758, 47.401737], [8.45828, 47.403974], [8.464815, 47.402626], [8.46546, 47.402431], [8.466099, 47.402221], [8.468701, 47.400985], [8.469319, 47.400607], [8.469932, 47.400195], [8.472234, 47.398559], [8.472778, 47.398163], [8.473409, 47.397736], [8.475991, 47.396189], [8.477326, 47.395505], [8.478077, 47.395143], [8.478837, 47.394834], [8.47958, 47.394548], [8.486803, 47.390898], [8.490284, 47.386612], [8.490429, 47.386559], [8.490432, 47.386558], [8.490577, 47.386505], [8.49245, 47.387122], [8.492643, 47.387395], [8.497143, 47.390353], [8.498112, 47.391577], [8.505916, 47.387689], [8.504898, 47.384236], [8.510534, 47.377512], [8.511196, 47.377231], [8.51998, 47.378327], [8.527845, 47.378362], [8.529417, 47.379045], [8.533442, 47.380079], [8.539795, 47.377412], [8.540452, 47.376804], [8.542126, 47.375373], [8.542514, 47.375167], [8.542884, 47.375138], [8.543177, 47.375136], [8.546936, 47.375226], [8.547208, 47.375267], [8.547634, 47.375355], [8.553136, 47.380895], [8.553526, 47.38319], [8.553188, 47.389464], [8.553301, 47.39029], [8.553905, 47.395308], [8.559711, 47.401473], [8.567638, 47.400049], [8.568619, 47.399533], [8.570436, 47.399557], [8.575348, 47.40162], [8.580763, 47.402633], [8.584389, 47.403115], [8.587957, 47.403594], [8.591472, 47.403151], [8.591971, 47.403089], [8.597968, 47.396734], [8.599575, 47.39

# %% [markdown]
# ## ranking for sochrone_within_10_mode_driving-car

# %%
sorted_gdf = sort_gdf_by_population_and_rename(gdf, 'isochrone_within_10_mode_driving-car')

import json
import folium

column_name = "isochrone_data"

# using Zurich as a default location
map_center = [47.3769, 8.5417]

# Initialize the map
m = folium.Map(location=map_center, zoom_start=10, tiles="CartoDB positron")

# Step 2: Add isochrones to the map
for idx, row in sorted_gdf.iterrows():
    if column_name in row and row[column_name]:
        try:
            isochrone_data = row[column_name]

            # Extract the center coordinates if they exist
            center_coords = isochrone_data["features"][0]["properties"].get("center", None)

            # Add the GeoJson layer representing the isochrone area
            folium.GeoJson(
                isochrone_data,
                name=f"Isochrone {idx}",
                style_function=lambda feature: {
                    "fillColor": "#FF7043",
                    "color": "#000000",
                    "weight": 2,
                    "dashArray": "5, 5",
                    "fillOpacity": 0.5,
                }
            ).add_to(m)

            # If center coordinates are available, add a marker
            if center_coords:
                folium.CircleMarker(
                    location=[center_coords[1], center_coords[0]],  # Lat, Long (reversed from GeoJSON)
                    radius=5,
                    color="red",
                    fill=True,
                    fill_color="red",
                    fill_opacity=1.0,
                    popup=f"Isochrone {idx} Center"
                ).add_to(m)
        except (json.JSONDecodeError, KeyError, IndexError) as e:
            print(f"Failed to handle row {idx}: {e}")

# Add layer control to toggle layers
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_602409bd9f7d2c217a5d9af6549c0ec7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_602409bd9f7d2c217a5d9af6549c0ec7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_602409bd9f7d2c217a5d9af6549c0ec7 = L.map(
#                 &quot;map_602409bd9f7d2c217a5d9af6549c0ec7&quot;,
#                 {
#                     center: [47.3769, 8.5417],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b479a247fa29b2efca434f0f2d321f59 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b479a247fa29b2efca434f0f2d321f59.addTo(map_602409bd9f7d2c217a5d9af6549c0ec7);
#
#
#         function geo_json_00cd4cd2d6ecfc5ce1ec558b6d30844b_styler(feature) {
#             switch(feature.properties.group_index) {
#                 default:
#                     return {&quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#FF7043&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_00cd4cd2d6ecfc5ce1ec558b6d30844b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_00cd4cd2d6ecfc5ce1ec558b6d30844b = L.geoJson(null, {
#                 onEachFeature: geo_json_00cd4cd2d6ecfc5ce1ec558b6d30844b_onEachFeature,
#
#                 style: geo_json_00cd4cd2d6ecfc5ce1ec558b6d30844b_styler,
#         });
#
#         function geo_json_00cd4cd2d6ecfc5ce1ec558b6d30844b_add (data) {
#             geo_json_00cd4cd2d6ecfc5ce1ec558b6d30844b
#                 .addData(data);
#         }
#             geo_json_00cd4cd2d6ecfc5ce1ec558b6d30844b_add({&quot;bbox&quot;: [8.426551, 47.394458, 8.595651, 47.46979], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.427068, 47.413072], [8.426551, 47.41061], [8.429777, 47.409105], [8.430029, 47.409023], [8.437622, 47.412509], [8.439317, 47.412644], [8.439898, 47.412729], [8.440441, 47.412915], [8.441332, 47.413353], [8.442965, 47.414105], [8.444472, 47.414942], [8.447837, 47.416734], [8.455924, 47.419244], [8.458141, 47.419545], [8.460298, 47.419809], [8.462477, 47.420077], [8.465345, 47.420376], [8.466689, 47.420502], [8.468202, 47.420639], [8.472422, 47.420983], [8.478647, 47.415438], [8.479484, 47.41283], [8.479548, 47.412721], [8.481457, 47.411864], [8.48683, 47.408988], [8.490963, 47.40331], [8.491973, 47.400875], [8.498148, 47.398855], [8.505342, 47.397574], [8.508381, 47.397076], [8.508564, 47.397056], [8.512846, 47.397186], [8.514572, 47.397287], [8.520846, 47.397624], [8.52885, 47.395991], [8.532005, 47.394476], [8.53212, 47.394458], [8.540044, 47.395323], [8.543361, 47.397401], [8.543659, 47.397863], [8.541717, 47.402744], [8.543205, 47.407305], [8.546976, 47.410282], [8.548341, 47.412434], [8.548415, 47.41352], [8.548481, 47.414074], [8.54988, 47.417785], [8.554763, 47.422878], [8.558664, 47.423428], [8.561856, 47.42358], [8.563092, 47.423333], [8.564367, 47.42313], [8.566316, 47.422888], [8.56787, 47.422603], [8.568944, 47.422375], [8.569606, 47.422266], [8.574141, 47.417441], [8.571914, 47.413532], [8.567416, 47.410791], [8.566794, 47.410299], [8.569027, 47.407475], [8.577125, 47.408934], [8.579173, 47.408454], [8.581358, 47.407941], [8.585266, 47.407046], [8.589234, 47.406137], [8.590436, 47.405905], [8.591209, 47.40578], [8.592, 47.405671], [8.593883, 47.405413], [8.595372, 47.405298], [8.595507, 47.40543], [8.595651, 47.408887], [8.595637, 47.409028], [8.594503, 47.409069], [8.59392, 47.409109], [8.592494, 47.409237], [8.591699, 47.409346], [8.591014, 47.409458], [8.58992, 47.409671], [8.586071, 47.410555], [8.582162, 47.411451], [8.579995, 47.411959], [8.577947, 47.412439], [8.574128, 47.418802], [8.575493, 47.422427], [8.575002, 47.426494], [8.574809, 47.42721], [8.573183, 47.433529], [8.572862, 47.438046], [8.572862, 47.438093], [8.572362, 47.443347], [8.569057, 47.444775], [8.568819, 47.444225], [8.560667, 47.440466], [8.560546, 47.4405], [8.560058, 47.440571], [8.559941, 47.440563], [8.551097, 47.442114], [8.545184, 47.44781], [8.544905, 47.448206], [8.54444, 47.448782], [8.537773, 47.454576], [8.537722, 47.454623], [8.53209, 47.460662], [8.531201, 47.461978], [8.530882, 47.462365], [8.530511, 47.462701], [8.530062, 47.46299], [8.529548, 47.463216], [8.521867, 47.460025], [8.518859, 47.46345], [8.515311, 47.465992], [8.514524, 47.466649], [8.514406, 47.466671], [8.509352, 47.466211], [8.508855, 47.464218], [8.508594, 47.462692], [8.511011, 47.456794], [8.511178, 47.456443], [8.51116, 47.449856], [8.508951, 47.444855], [8.50157, 47.447367], [8.495493, 47.453288], [8.497011, 47.461113], [8.498155, 47.462271], [8.498601, 47.463467], [

# %% [markdown]
# ## ranking for sochrone_within_5_mode_driving-car

# %%
sorted_gdf = sort_gdf_by_population_and_rename(gdf, 'isochrone_within_5_mode_driving-car')

import json
import folium

column_name = "isochrone_data"

# using Zurich as a default location
map_center = [47.3769, 8.5417]

# Initialize the map
m = folium.Map(location=map_center, zoom_start=10, tiles="CartoDB positron")

# Step 2: Add isochrones to the map
for idx, row in sorted_gdf.iterrows():
    if column_name in row and row[column_name]:
        try:
            isochrone_data = row[column_name]

            # Extract the center coordinates if they exist
            center_coords = isochrone_data["features"][0]["properties"].get("center", None)

            # Add the GeoJson layer representing the isochrone area
            folium.GeoJson(
                isochrone_data,
                name=f"Isochrone {idx}",
                style_function=lambda feature: {
                    "fillColor": "#42A5F5",
                    "color": "#000000",
                    "weight": 2,
                    "dashArray": "5, 5",
                    "fillOpacity": 0.5,
                }
            ).add_to(m)

            # If center coordinates are available, add a marker
            if center_coords:
                folium.CircleMarker(
                    location=[center_coords[1], center_coords[0]],  # Lat, Long (reversed from GeoJSON)
                    radius=5,
                    color="red",
                    fill=True,
                    fill_color="red",
                    fill_opacity=1.0,
                    popup=f"Isochrone {idx} Center"
                ).add_to(m)
        except (json.JSONDecodeError, KeyError, IndexError) as e:
            print(f"Failed to handle row {idx}: {e}")

# Add layer control to toggle layers
folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69abc074065dc8cc6f39223180e6b60c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69abc074065dc8cc6f39223180e6b60c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69abc074065dc8cc6f39223180e6b60c = L.map(
#                 &quot;map_69abc074065dc8cc6f39223180e6b60c&quot;,
#                 {
#                     center: [47.3769, 8.5417],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2c098bdcdbd33ef26d3ae7e842425d6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2c098bdcdbd33ef26d3ae7e842425d6.addTo(map_69abc074065dc8cc6f39223180e6b60c);
#
#
#         function geo_json_957e781b45300abb29604490729cf07a_styler(feature) {
#             switch(feature.properties.group_index) {
#                 default:
#                     return {&quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#42A5F5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_957e781b45300abb29604490729cf07a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_957e781b45300abb29604490729cf07a = L.geoJson(null, {
#                 onEachFeature: geo_json_957e781b45300abb29604490729cf07a_onEachFeature,
#
#                 style: geo_json_957e781b45300abb29604490729cf07a_styler,
#         });
#
#         function geo_json_957e781b45300abb29604490729cf07a_add (data) {
#             geo_json_957e781b45300abb29604490729cf07a
#                 .addData(data);
#         }
#             geo_json_957e781b45300abb29604490729cf07a_add({&quot;bbox&quot;: [8.768522, 47.292043, 8.824004, 47.335022], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.772572, 47.325385], [8.774324, 47.322496], [8.769392, 47.316719], [8.768802, 47.316772], [8.768528, 47.316773], [8.768522, 47.313173], [8.768679, 47.308442], [8.769869, 47.306288], [8.775078, 47.302856], [8.776576, 47.302141], [8.776928, 47.30223], [8.779652, 47.302476], [8.785905, 47.297493], [8.78744, 47.295467], [8.788042, 47.295235], [8.796766, 47.293182], [8.797388, 47.292797], [8.798109, 47.292362], [8.79869, 47.292043], [8.803602, 47.293823], [8.804283, 47.294265], [8.804202, 47.296492], [8.804199, 47.296494], [8.802324, 47.297284], [8.800154, 47.298885], [8.799782, 47.299055], [8.795674, 47.304638], [8.79757, 47.308929], [8.802753, 47.310995], [8.806222, 47.309734], [8.808865, 47.308069], [8.809314, 47.307905], [8.809502, 47.307829], [8.812354, 47.306028], [8.813269, 47.304945], [8.815743, 47.306269], [8.821764, 47.311234], [8.822874, 47.311896], [8.823841, 47.314174], [8.824004, 47.320192], [8.823702, 47.321656], [8.822943, 47.325286], [8.821149, 47.331635], [8.820407, 47.332959], [8.817568, 47.334784], [8.81751, 47.334811], [8.816921, 47.334972], [8.810187, 47.334555], [8.806595, 47.334716], [8.805181, 47.334757], [8.797154, 47.334007], [8.795867, 47.334006], [8.795553, 47.334003], [8.791275, 47.332074], [8.786129, 47.333068], [8.781308, 47.335022], [8.774354, 47.334061], [8.772666, 47.333347], [8.77258, 47.333295], [8.771482, 47.331891], [8.772572, 47.325385]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;center&quot;: [8.794555635970186, 47.31675117501324], &quot;group_index&quot;: 0, &quot;total_pop&quot;: 25843.0, &quot;value&quot;: 300.0}, &quot;type&quot;: &quot;Feature&quot;}], &quot;metadata&quot;: {&quot;attribution&quot;: &quot;openrouteservice.org | OpenStreetMap contributors&quot;, &quot;engine&quot;: {&quot;build_date&quot;: &quot;2024-03-21T13:55:54Z&quot;, &quot;graph_date&quot;: &quot;2024-05-05T19:27:52Z&quot;, &quot;version&quot;: &quot;8.0.0&quot;}, &quot;query&quot;: {&quot;attributes&quot;: [&quot;total_pop&quot;], &quot;locations&quot;: [[8.794989888700059, 47.31702359077988]], &quot;profile&quot;: &quot;driving-car&quot;, &quot;range&quot;: [300.0], &quot;range_type&quot;: &quot;time&quot;}, &quot;service&quot;: &quot;isochrones&quot;, &quot;timestamp&quot;: 1715418771086}, &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_957e781b45300abb29604490729cf07a.addTo(map_69abc074065dc8cc6f39223180e6b60c);
#
#
#             var circle_marker_9a4549e8fb538b08b3128381cb4960ea = L.circleMarker(
#                 [47.31675117501324, 8.794555635970186],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1.0, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap

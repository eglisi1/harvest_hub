# %%
import json

with open("../data/farm_details.json") as f:
    farm_data = json.load(f)

# %%
# remove the first line from each address

for farm in farm_data:
    # Get the full address from the farm data
    address = farm["info"]["address"]

    # Split the address by newline character and keep everything after the first line
    parts = address.split("\n")
    if len(parts) > 1:
        # Join the parts back, excluding the first line
        updated_address = "\n".join(parts[1:])
        farm["info"]["address"] = updated_address

# %% [markdown]
# ## define base url for search

# %%
import requests

# Define base url for address search
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Set up search parameters: address, origins and type
parameters = {"searchText": "8400 Winterthur, Theaterstrasse 17",
              "origins": "address",
              "type": "locations",
             }

# Urllib.parse.urlencode turns parameters into url
# print(f"{base_url}{urllib.parse.urlencode(parameters)}")

# %%
import urllib
import pandas as pd

# Server request
r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

# Get data in json-format
data = json.loads(r.content)
data

# Take only the first server response, convert to data frame with relevant infos
df = pd.DataFrame.from_dict(list(data.values())[0][0], orient='columns')
df.iloc[[1,4,5,6,11,12],:1]
# Out:
#                                               attrs
# featureId                                 2323240_0
# label      Theaterstrasse 17 <b>8400 Winterthur</b>
# lat                                       47.503517
# lon                                        8.727852
# x                                        262216.125
# y                                       697128.5625

# %%
from typing import Dict


def get_coordinates(address: str, verbose: bool = False) -> Dict[float, float]:
    base_url = "https://api3.geo.admin.ch/rest/services/api/SearchServer?"
    parameters = {
        "searchText": address,
        "origins": "address",
        "type": "locations",
    }

    response = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")
    data = json.loads(response.content)

    if "results" in data and data["results"]:
        attrs = data["results"][0]["attrs"]
        if "lat" in attrs and "lon" in attrs:
            return {"lat": attrs["lat"], "lon": attrs["lon"]}
        else:
            print(f"Latitude and longitude not found in the results for address {address}") if verbose else None
    else:
        print(f"Unexpected data structure for address {address}: {data}") if verbose else None

    return None

# %%
valid_farms = []
amount_errors = 0

for farm in farm_data:
    address = farm['info']['address']
    coordinates = get_coordinates(address)
    if coordinates:
        farm['info']['coordinates'] = coordinates
        valid_farms.append(farm)
    else:
        amount_errors += 1

print(f"Amount of farms with errors: {amount_errors}")
print(f"In percentage: {amount_errors / len(farm_data) * 100}%")
# Out:
# Amount of farms with errors: 16
# In percentage: 4.289544235924933%

# %%
farm_data = valid_farms

geojson = {
    "type": "FeatureCollection",
    "name": "buildings",
    "crs": {"type": "name", "properties": {"name": "urn:ogc:def:crs:EPSG::2056"}},
    "features": [],
}

# Convert each farm entry to a GeoJSON feature
for farm in farm_data:
    feature = {
        "type": "Feature",
        "properties": {
            "name": farm["name"],
            "address": farm["info"]["address"],
            "lebensmittel": farm["info"]["lebensmittel"],
            # more properties if needed
        },
        "geometry": {
            "type": "Point",
            "coordinates": [
                farm["info"]["coordinates"]["lon"],
                farm["info"]["coordinates"]["lat"],
            ],
        },
    }
    geojson["features"].append(feature)
# Out:
# {
#     "type": "FeatureCollection",
#     "name": "buildings",
#     "crs": {
#         "type": "name",
#         "properties": {
#             "name": "urn:ogc:def:crs:EPSG::2056"
#         }
#     },
#     "features": [
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Ritzmann-Müller Betriebsgemeinschaft, 8459 Volken",
#                 "address": "Flaachtalstr. 43\n8459 Volken",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Kartoffeln",
#                             "Weisskohl",
#                             "Zwiebeln"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Likör",
#                             "Marc",
#                             "Roséwein",
#                             "Rotwein",
#                             "Traubensaft",
#                             "Weisswein"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Trauben"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.623202323913574,
#                     47.57524490356445
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Bauernhof Familie Werffeli, 8104 Weiningen",
#                 "address": "Friedhofstrasse 4\n8104 Weiningen",
#                 "lebensmittel": [
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Kalbfleisch",
#                             "Rindfleisch",
#                             "Schweinefleisch",
#                             "Wild",
#                             "Wurstwaren"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Hanfsamen",
#                             "Kartoffeln",
#                             "Leinsamen"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Roséwein",
#                             "Rotwein",
#                             "Schaumwein",
#                             "Traubensaft",
#                             "Weisswein"
#                         ]
#                     },
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Käse",
#                             "Milch"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Honig"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.43603229522705,
#                     47.421749114990234
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Hof zur Au, 8165 Schleinikon",
#                 "address": "Auweg 3\n8165 Schleinikon",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Dienstleistungen",
#                         "products": [
#                             "Baumschneiden"
#                         ]
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel",
#                             "Erdbeeren",
#                             "Himbeeren",
#                             "Kirschen",
#                             "Mirabellen",
#                             "Quitten",
#                             "Zwetschgen"
#                         ]
#                     },
#                     {
#                         "category": "Holz",
#                         "products": [
#                             "Cheminée-Holz"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.396893501281738,
#                     47.49842834472656
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Sonnhaldenhof, 5610 Wohlen",
#                 "address": "Sonnhaldenhof\n5610 Wohlen",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Blumen und Pflanzen",
#                         "products": [
#                             "Schnittblumen"
#                         ]
#                     },
#                     {
#                         "category": "Geschenke und Handwerk",
#                         "products": [
#                             "Geschenkkorb"
#                         ]
#                     },
#                     {
#                         "category": "Brot, Getreide und Teigwaren",
#                         "products": [
#                             "Brot"
#                         ]
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Kalbfleisch",
#                             "Wurstwaren"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Spargeln",
#                             "Süsskartoffeln"
#                         ]
#                     },
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Milch"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel",
#                             "Himbeeren"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Honig",
#                             "Konfitüren"
#                         ]
#                     },
#                     {
#                         "category": "Freizeit und Erlebnis",
#                         "products": [
#                             "Räumlichkeiten",
#                             "Spielplatz"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.292679786682129,
#                     47.342262268066406
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Streulis Privatbrennerei, 8810 Horgen",
#                 "address": "Rietwiesstrasse 139\n8810 Horgen",
#                 "lebensmittel": [
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Gin",
#                             "Gin",
#                             "Kirsch",
#                             "Kirsch",
#                             "Likör",
#                             "Likör",
#                             "Likör",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Obstbrand",
#                             "Zwetschgenschnaps",
#                             "Zwetschgenschnaps"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.628228187561035,
#                     47.23968505859375
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Bio Waidhof, 8052 Zürich",
#                 "address": "Schwandenholzstrasse 157\n8052 Zürich",
#                 "lebensmittel": [
#                     {
#                         "category": "Brot, Getreide und Teigwaren",
#                         "products": [
#                             "Getreideflocken"
#                         ]
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Wurstwaren"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Kartoffeln"
#                         ]
#                     },
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Milch"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Honig",
#                             "Speiseöl"
#                         ]
#                     },
#                     {
#                         "category": "Tiere",
#                         "products": [
#                             "Heu und Emd"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.52527141571045,
#                     47.42348098754883
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Gfellerhof und Kämatten, 8051 Zürich",
#                 "address": "Stettbachstrasse 90\n8051 Zürich",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft"
#                         ]
#                     },
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Milch"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.587959289550781,
#                     47.393131256103516
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Schumacher Agrobetrieb, 8046 Zürich",
#                 "address": "Katzenseestrasse 8\n8046 Zürich",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Blumen und Pflanzen",
#                         "products": [
#                             "Arrangements / Gestecke"
#                         ]
#                     },
#                     {
#                         "category": "Dienstleistungen",
#                         "products": [
#                             "Lohnarbeiten"
#                         ]
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Wurstwaren"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Gurken",
#                             "Kartoffeln",
#                             "Kürbis",
#                             "Salate",
#                             "Tomaten"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Guetzli",
#                             "Honig"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.506240844726562,
#                     47.426841735839844
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Riedenholzhof, 8052 Zürich",
#                 "address": "Riedenholzstrasse 122\n8052 Zürich",
#                 "lebensmittel": [
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Rindfleisch",
#                             "Schweinefleisch"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Sirup"
#                         ]
#                     },
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Käse",
#                             "Milch"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Brombeeren",
#                             "Heidelbeeren",
#                             "Himbeeren"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Honig",
#                             "Konfitüren"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.528615951538086,
#                     47.43193435668945
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Pfister Gemüsebau, 8427 Freienstein",
#                 "address": "Rüedi 5\n8427 Freienstein",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Blumen und Pflanzen",
#                         "products": [
#                             "Schnittblumen"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Artischocken",
#                             "Basilikum",
#                             "Bohnen",
#                             "Bohnenkraut",
#                             "Cicorino",
#                             "Dill",
#                             "Endivien",
#                             "Erbsen",
#                             "Federkohl",
#                             "Fenchel",
#                             "Gurken",
#                             "Kardy",
#                             "Kartoffeln",
#                             "Krautstiel / Mangold",
#                             "Palmkohl",
#                             "Peperoni",
#                             "Pfefferminze",
#                             "Rettich",
#                             "Rosmarin",
#                             "Salbei",
#                             "Spitzkohl",
#                             "Tomaten",
#                             "Topinambur",
#                             "Zucchetti",
#                             "Zwiebeln"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Erdbeeren"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.599169731140137,
#                     47.535579681396484
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "peter-rickenbach.ch, 8545 Rickenbach",
#                 "address": "Dorfstrasse 4\n8545 Rickenbach",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Brot, Getreide und Teigwaren",
#                         "products": [
#                             "Mehl"
#                         ]
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Rindfleisch"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Kartoffeln",
#                             "Lindenblüten",
#                             "Spargeln",
#                             "Tomaten",
#                             "Zwiebeln"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft",
#                             "Rotwein",
#                             "Traubensaft",
#                             "Weisswein"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Glacé",
#                             "Honig"
#                         ]
#                     },
#                     {
#                         "category": "Dienstleistungen",
#                         "products": [
#                             "Lohnarbeiten"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.7951021194458,
#                     47.55210876464844
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Bihr Rosengartenprodukte, 8344 Bäretswil",
#                 "address": "Schönaustr. 67\n8344 Bäretswil",
#                 "lebensmittel": [
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Kalbfleisch",
#                             "Kaninchenfleisch",
#                             "Lammfleisch",
#                             "Rindfleisch",
#                             "Schweinefleisch",
#                             "Trutenfleisch"
#                         ]
#                     },
#                     {
#                         "category": "Ferienangebote",
#                         "products": []
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.862698554992676,
#                     47.32330322265625
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Hofladen Langwies, Ringlikon, 8142 Uitikon Waldegg",
#                 "address": "Langwiesstrasse 35\n8142 Uitikon Waldegg",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Brot, Getreide und Teigwaren",
#                         "products": [
#                             "Gebäck süss"
#                         ]
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Rindfleisch"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Kartoffeln"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft",
#                             "Apfelsaft"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel",
#                             "Apfelringli",
#                             "Birnen",
#                             "Kirschen",
#                             "Zwetschgen"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Gelee",
#                             "Konfitüren",
#                             "Konfitüren",
#                             "Meringues"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.469846725463867,
#                     47.357521057128906
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Steigacher, 8311 Brütten",
#                 "address": "Steigacher 3\n8311 Brütten",
#                 "lebensmittel": [
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft",
#                             "Obstbrand",
#                             "Weisswein",
#                             "Zwetschgenschnaps"
#                         ]
#                     },
#                     {
#                         "category": "Holz",
#                         "products": [
#                             "Cheminée-Holz"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.688177108764648,
#                     47.469486236572266
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Brachland, 8608 Bubikon",
#                 "address": "Brachstrasse 12\n8608 Bubikon",
#                 "lebensmittel": [
#                     {
#                         "category": "Dienstleistungen",
#                         "products": [
#                             "Unterhaltsarbeiten"
#                         ]
#                     },
#                     {
#                         "category": "Freizeit und Erlebnis",
#                         "products": [
#                             "Erlebnisangebote",
#                             "Erlebnisferien",
#                             "Events",
#                             "Firmenanlass",
#                             "Räumlichkeiten",
#                             "Schullager / Schulreise"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Bohnen",
#                             "Kefen",
#                             "Knoblauch",
#                             "Lindenblüten",
#                             "Meerrettich",
#                             "Schnittsalat",
#                             "Tomaten",
#                             "Zwiebeln"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Obstbrand"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel",
#                             "Brombeeren",
#                             "Heidelbeeren",
#                             "Himbeeren",
#                             "Johannisbeeren",
#                             "Stachelbeeren"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Essig"
#                         ]
#                     },
#                     {
#                         "category": "Ferienangebote",
#                         "products": []
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.813812255859375,
#                     47.27959060668945
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Weingut Gehring, 8427  Freienstein",
#                 "address": "Im Geissstig 4\n8427 Freienstein",
#                 "lebensmittel": [
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Rotwein",
#                             "Schaumwein",
#                             "Weisswein"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.590897560119629,
#                     47.537071228027344
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Widem, 8164 Bachs",
#                 "address": "Widemstrasse 25\n8164 Bachs",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft",
#                             "Likör",
#                             "Sirup"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Dörrfrüchte"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Gelee",
#                             "Konfitüren"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.438129425048828,
#                     47.52803039550781
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Gutsbetrieb Uf-Stocken, 8802 Kilchberg",
#                 "address": "Stockenstrasse 88\n8802 Kilchberg",
#                 "lebensmittel": [
#                     {
#                         "category": "Brot, Getreide und Teigwaren",
#                         "products": [
#                             "Brot",
#                             "Teigwaren",
#                             "Zopf"
#                         ]
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Mischpaket",
#                             "Rindfleisch",
#                             "Wurstwaren"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Karotten",
#                             "Kartoffeln",
#                             "Salate",
#                             "Zwiebeln"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft",
#                             "Apfelwein",
#                             "Sirup"
#                         ]
#                     },
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Butter",
#                             "Joghurt",
#                             "Milch"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Essig",
#                             "Guetzli",
#                             "Honig",
#                             "Konfitüren",
#                             "Speiseöl"
#                         ]
#                     },
#                     {
#                         "category": "Geschenke und Handwerk",
#                         "products": [
#                             "Geschenkkorb"
#                         ]
#                     },
#                     {
#                         "category": "Holz",
#                         "products": [
#                             "Weihnachtsbäume"
#                         ]
#                     },
#                     {
#                         "category": "Tiere",
#                         "products": [
#                             "Stroh"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.540152549743652,
#                     47.32370376586914
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Brachers Blumenfeld, 3423 Ersigen",
#                 "address": "Huebstrasse 12\n3423 Ersigen",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Blumen und Pflanzen",
#                         "products": [
#                             "Schnittblumen"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Rindfleisch"
#                         ]
#                     },
#                     {
#                         "category": "Freizeit und Erlebnis",
#                         "products": [
#                             "Bar",
#                             "Restaurant"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     7.605047225952148,
#                     47.09979248046875
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Bergli Christbaum, 8707 Uetikon am See",
#                 "address": "Holländerstrasse 71\n8707 Uetikon am See",
#                 "lebensmittel": [
#                     {
#                         "category": "Holz",
#                         "products": [
#                             "Weihnachtsbäume"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.68210220336914,
#                     47.27384567260742
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Gemüse vom Ankenhof, 8102 Oberengstringen",
#                 "address": "Ankenhofstrasse 12\n8102 Oberengstringen",
#                 "lebensmittel": [
#                     {
#                         "category": "Blumen und Pflanzen",
#                         "products": [
#                             "Samen und Setzlinge"
#                         ]
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Auberginen",
#                             "Basilikum",
#                             "Blumenkohl",
#                             "Broccoli",
#                             "Eingemachtes Gemüse",
#                             "Fenchel",
#                             "Karotten",
#                             "Kartoffeln",
#                             "Kohlrabi",
#                             "Radieschen",
#                             "Salate",
#                             "Schnittsalat",
#                             "Sellerie",
#                             "Tomaten",
#                             "Zwiebeln"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft",
#                             "Traubensaft"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel",
#                             "Birnen",
#                             "Melonen"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Gelee",
#                             "Honig",
#                             "Konfitüren"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.463837623596191,
#                     47.4108772277832
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Egghof, 3429 Höchstetten",
#                 "address": "Zürich-Bernstrasse 10\n3429 Höchstetten",
#                 "lebensmittel": [
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Frühkartoffeln",
#                             "Kartoffeln"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Früchtemix"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     7.630258083343506,
#                     47.14130783081055
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "BungertHof, 8415 Berg am Irchel",
#                 "address": "Chileweg 4\n8415 Berg am Irchel",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Freizeit und Erlebnis",
#                         "products": [
#                             "Schullager / Schulreise"
#                         ]
#                     },
#                     {
#                         "category": "Ferienangebote",
#                         "products": []
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.597627639770508,
#                     47.570289611816406
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Traub Bio-Gemüse Eichhof, 5608 Stetten",
#                 "address": "Eichhof 6\n5608 Stetten",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Salate",
#                             "Tomaten",
#                             "Zucchetti"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Erdbeeren"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.294594764709473,
#                     47.406944274902344
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Hofkäserei im Basi, 8953 Dietikon",
#                 "address": "Alte Kindhauserstrasse 3\n8953 Dietikon",
#                 "lebensmittel": [
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Kartoffeln"
#                         ]
#                     },
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Joghurt",
#                             "Käse",
#                             "Milch",
#                             "Quark"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel",
#                             "Zwetschgen"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.39218807220459,
#                     47.397239685058594
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Erdbeer- und Kefenfeld, Widmers Selbstpflückparadies , 3429 Höchstetten",
#                 "address": "Steingasse 12\n3429 Höchstetten",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Artischocken",
#                             "Erbsen",
#                             "Kefen",
#                             "Rhabarber",
#                             "Tomaten"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel",
#                             "Baumnüsse",
#                             "Birnen",
#                             "Erdbeeren",
#                             "Himbeeren",
#                             "Quitten"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     7.631537437438965,
#                     47.14338302612305
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Züri Oberländer Sträusse, 8332 Russikon",
#                 "address": "Obermoos 32\n8332 Russikon",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Blumen und Pflanzen",
#                         "products": [
#                             "Schnittblumen"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.765241622924805,
#                     47.399505615234375
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Leutenegger Schafkäse , 8577 Schönholzerswilen",
#                 "address": "Leutenegg 7\n8577 Schönholzerswilen",
#                 "lebensmittel": [
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Schafkäse",
#                             "Schafmilch",
#                             "Schafmilchjoghurt"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     9.140642166137695,
#                     47.49760437011719
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Käsers Schloss AG, 5077 Elfingen",
#                 "address": "Schloss 17 c\n5077 Elfingen",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Dienstleistungen",
#                         "products": [
#                             "Gemüse-Abo"
#                         ]
#                     },
#                     {
#                         "category": "Freizeit und Erlebnis",
#                         "products": [
#                             "Führungen / Hofbesichtigung",
# ...
#                 "name": "Biohof Birch5, 8340 Hinwil",
#                 "address": "Birchstrasse 5\n8340 Hinwil",
#                 "lebensmittel": [
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Rindfleisch"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Kartoffeln"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.855253219604492,
#                     47.28461456298828
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Hauser / Binder Widmen 22, 8634 Hombrechtikon",
#                 "address": "Widmen 22\n8634 Hombrechtikon",
#                 "lebensmittel": [
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Sirup"
#                         ]
#                     },
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Käse"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Konfitüren"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.755358695983887,
#                     47.2463493347168
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Eberhard-Hasel-Hombrechtikon, 8634 Hombrechtikon",
#                 "address": "Hasel 6\n8634 Hombrechtikon",
#                 "lebensmittel": [
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Lammfleisch"
#                         ]
#                     },
#                     {
#                         "category": "Freizeit und Erlebnis",
#                         "products": [
#                             "Restaurant"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.775925636291504,
#                     47.263484954833984
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "BG Grob Schmid, 8543 Bertschikon",
#                 "address": "Wiesendangerstrasse 3a\n8543 Bertschikon",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Kalbfleisch",
#                             "Poulet",
#                             "Wurstwaren"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft"
#                         ]
#                     },
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Käse",
#                             "Milch"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Baumnüsse"
#                         ]
#                     },
#                     {
#                         "category": "Holz",
#                         "products": [
#                             "Brennholz",
#                             "Finnenkerzen",
#                             "Holzschnitzel"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.813760757446289,
#                     47.526004791259766
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Husacher, 8424 Embrach",
#                 "address": "Husacher 155\n8424 Embrach",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Gänsefleisch",
#                             "Mischpaket",
#                             "Rindfleisch",
#                             "Trutenfleisch",
#                             "Wurstwaren"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.581558227539062,
#                     47.49386215209961
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Kappeler , 8544 Attikon",
#                 "address": "Gigerstrasse 3\n8544 Attikon",
#                 "lebensmittel": [
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Spargeln"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.797846794128418,
#                     47.53956604003906
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Unterwagenburg, 8425 Oberembrach",
#                 "address": "Unterwagenburg 1a\n8425 Oberembrach",
#                 "lebensmittel": [
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Spargeln"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.645666122436523,
#                     47.489784240722656
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Bahn-Hof, 8468 Guntalingen",
#                 "address": "Dorfstrasse 2\n8468 Guntalingen",
#                 "lebensmittel": [
#                     {
#                         "category": "Brot, Getreide und Teigwaren",
#                         "products": [
#                             "Brot",
#                             "Mehl"
#                         ]
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier",
#                             "Wachteleier"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Bohnen",
#                             "Frühkartoffeln",
#                             "Gurken",
#                             "Kartoffeln",
#                             "Kopfsalat",
#                             "Randen",
#                             "Zwiebeln"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft"
#                         ]
#                     },
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Joghurt",
#                             "Käse",
#                             "Milch"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel",
#                             "Dörrfrüchte",
#                             "Kirschen"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Konfitüren"
#                         ]
#                     },
#                     {
#                         "category": "Holz",
#                         "products": [
#                             "Brennholz"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.76731014251709,
#                     47.62861251831055
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Obholzerstübli, 8309 Nürensdorf",
#                 "address": "Obholz 4\n8309 Nürensdorf",
#                 "lebensmittel": [
#                     {
#                         "category": "Brot, Getreide und Teigwaren",
#                         "products": [
#                             "Brot",
#                             "Zopf"
#                         ]
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Kalbfleisch"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Kartoffeln",
#                             "Knoblauch"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft",
#                             "Likör",
#                             "Sirup",
#                             "Weinbrand"
#                         ]
#                     },
#                     {
#                         "category": "Milchprodukte",
#                         "products": [
#                             "Käse"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Äpfel",
#                             "Baumnüsse",
#                             "Zwetschgen"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Honig"
#                         ]
#                     },
#                     {
#                         "category": "Freizeit und Erlebnis",
#                         "products": [
#                             "Räumlichkeiten"
#                         ]
#                     },
#                     {
#                         "category": "Geschenke und Handwerk",
#                         "products": [
#                             "Geschenkkorb"
#                         ]
#                     },
#                     {
#                         "category": "Holz",
#                         "products": [
#                             "Cheminée-Holz"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.62768268585205,
#                     47.463809967041016
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Schlattgut, 8704 Herrliberg",
#                 "address": "Schlattstrasse 67\n8704 Herrliberg",
#                 "lebensmittel": [
#                     {
#                         "category": "Verkaufsstellen",
#                         "products": []
#                     },
#                     {
#                         "category": "Brot, Getreide und Teigwaren",
#                         "products": [
#                             "Brot",
#                             "Teigwaren"
#                         ]
#                     },
#                     {
#                         "category": "Eier",
#                         "products": [
#                             "Hühnereier"
#                         ]
#                     },
#                     {
#                         "category": "Fleisch",
#                         "products": [
#                             "Rindfleisch"
#                         ]
#                     },
#                     {
#                         "category": "Gemüse und andere pflanzliche Produkte",
#                         "products": [
#                             "Kartoffeln"
#                         ]
#                     },
#                     {
#                         "category": "Getränke",
#                         "products": [
#                             "Apfelsaft"
#                         ]
#                     },
#                     {
#                         "category": "Obst, Beeren und Nüsse",
#                         "products": [
#                             "Erdbeeren"
#                         ]
#                     },
#                     {
#                         "category": "Weitere Produkte",
#                         "products": [
#                             "Glacé",
#                             "Honig",
#                             "Konfitüren"
#                         ]
#                     },
#                     {
#                         "category": "Freizeit und Erlebnis",
#                         "products": [
#                             "Bauernhofspiele",
#                             "Besenbeiz",
#                             "Events",
#                             "Firmenanlass",
#                             "Führungen / Hofbesichtigung",
#                             "Hochzeit",
#                             "Räumlichkeiten"
#                         ]
#                     },
#                     {
#                         "category": "Geschenke und Handwerk",
#                         "products": [
#                             "Geschenkkorb"
#                         ]
#                     }
#                 ]
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     8.627480506896973,
#                     47.28927993774414
#                 ]
#             }
#         }
#     ]
# }

# %%
with open('../data/farms.geojson', 'w', encoding='utf-8') as file:
    json.dump(geojson, file, ensure_ascii=False, indent=4)
